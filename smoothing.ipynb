# %% [markdown]
# # Averaging

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

img = cv2.imread('images/smooth.jpg',1)

blur = cv2.blur(img,(21,21))

plt.subplot(121),plt.imshow(img),plt.title('original')
plt.xticks([]), plt.yticks([])
plt.subplot(122),plt.imshow(blur),plt.title('blurred')
plt.xticks([]), plt.yticks([])
plt.show()

# %% [markdown]
# # Gaussian Blurring

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

img = cv2.imread('../images/trees.jpg',1)

blur = cv2.GaussianBlur(img,(21,21),0)

plt.subplot(121),plt.imshow(img),plt.title('original')
plt.xticks([]), plt.yticks([])
plt.subplot(122),plt.imshow(blur),plt.title('blurred')
plt.xticks([]), plt.yticks([])
plt.show()
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-2-9242507a07ec> in <module>()
#       5 img = cv2.imread('../images/trees.jpg',1)
#       6
# ----> 7 blur = cv2.GaussianBlur(img,(21,21),0)
#       8
#       9 plt.subplot(121),plt.imshow(img),plt.title('original')
#
# error: C:\bld\opencv_1498171314629\work\opencv-3.2.0\modules\core\src\matrix.cpp:949: error: (-215) dims <= 2 && step[0] > 0 in function cv::Mat::locateROI

# %% [markdown]
# # Median Blurring

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

img = cv2.imread('../images/flower.jpg',1)

RGB_img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

median = cv2.medianBlur(RGB_img,9)

plt.subplot(121),plt.imshow(RGB_img),plt.title('original')
plt.xticks([]), plt.yticks([])
plt.subplot(122),plt.imshow(median),plt.title('blurred')
plt.xticks([]), plt.yticks([])
plt.show()
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-3-c68a46b0c2d9> in <module>()
#       5 img = cv2.imread('../images/flower.jpg',1)
#       6
# ----> 7 RGB_img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
#       8
#       9 median = cv2.medianBlur(RGB_img,9)
#
# error: C:\bld\opencv_1498171314629\work\opencv-3.2.0\modules\imgproc\src\color.cpp:9716: error: (-215) scn == 3 || scn == 4 in function cv::cvtColor

# %% [markdown]
# # Bilateral Filtering

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

img = cv2.imread('../images/flower.jpg')

RGB_img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

bilateral = cv2.bilateralFilter(RGB_img,9,75,75)

plt.subplot(121),plt.imshow(RGB_img),plt.title('original')
plt.xticks([]), plt.yticks([])
plt.subplot(122),plt.imshow(bilateral),plt.title('blurred')
plt.xticks([]), plt.yticks([])
plt.show()
